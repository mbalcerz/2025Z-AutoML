# %%
import importlib
import json
import pandas as pd
import numpy as np
import time
import warnings
import importlib
from sklearn.datasets import fetch_openml 
from xgboost import XGBClassifier, XGBRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVC, SVR
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PowerTransformer, OneHotEncoder, LabelEncoder
import os
warnings.filterwarnings('ignore')

# %% [markdown]
# # Ostateczna ocena konfiguracji i zapis do pliku

# %% [markdown]
# Przeprowadzimy teraz screening 50 konfiguracji na różnych zbioroach danych zOpenML (w tym niezbalansowanych), ograniczonych do 5000 próbek w celu szybkiej weryfikacji zdolnosci generalizacji oraz potencjału do roziwązywania wielu problemów.

# %%
datasets = {
    1510: "WBC (Breast Cancer)",    
    1462: "Banknote Auth",          
    37:   "Diabetes (Pima)",
    1461: "Bank Marketing",         
    1049: "PC4 (Software Defect)",  
    1464: "Blood Transfusion", 
    1485: "Madelon",                
    1479: "Hill-Valley",            
    40994: "Climate Crashes",
    31:   "German Credit",          
    44:   "Spambase",               
    1494: "QSAR Biodeg", 
}

# %%
def get_class(path):
    """Dynamically load a class from a configuration string."""
    module_path, class_name = path.rsplit('.', 1)
    module = importlib.import_module(module_path)
    return getattr(module, class_name)

def load_models_from_json(path):
    """Load model configurations from a JSON file."""
    with open(path, 'r') as f:
        try:
            models = json.load(f)
            print(f"Loaded {len(models)} models from file '{path}'")
            return models
        except json.JSONDecodeError as e:
            print(e)
            return []
        
# zdefiniujemy pipeline który użyjemy prawdopodobnie w systemie miniautoml
def build_pipeline(model, X):
    numeric_features = X.select_dtypes(include=['int64', 'float64']).columns
    categorical_features = X.select_dtypes(include=['object', 'category', 'bool']).columns
    
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', PowerTransformer(method='yeo-johnson')) 
    ])
    
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])
    
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features),
            ('cat', categorical_transformer, categorical_features)
        ],
        verbose_feature_names_out=False
    )
    
    return Pipeline(steps=[('preprocessor', preprocessor), ('classifier', model)])

# załadujemy dane z openml o danych z datasets; nie chcemy pełnych zbiorów tylko próbki do 5000 rekordów aby zorientować się w działaniu modeli

def load_openml(datesets_id, name):
    try:
        X,y = fetch_openml(data_id=datesets_id, as_frame=True, return_X_y=True, parser='auto')
        if len(X) > 5000:
            X = X.sample(5000, random_state=42)
            y = y.loc[X.index]
        le = LabelEncoder()
        y = le.fit_transform(y)
        if len(np.unique(y))!=2:
            print(f"Dataset {name} (ID: {datesets_id}) is not binary classification, skipping.")
            return None, None
        print(f"Loaded dataset {name} (ID: {datesets_id}) with {X.shape[0]} samples and {X.shape[1]} features.")
        return X, y
    except Exception as e:
        print(e)
        return None, None

# %%
def run(json_path):
    models_config = load_models_from_json(json_path)
    if not models_config:
        print("No models to evaluate.")
        return
    results = []
    for d_id, d_name in datasets.items():
        print(f"\n--- RUNDA: {d_name} ---")
        X, y = load_openml(d_id, d_name)
        
        if X is None: continue
        
        for config in models_config:
            model_name = config['name']
            
            try:
                ModelClass = get_class(config['class'])
                clf = ModelClass(**config['params'])
                full_pipeline = build_pipeline(clf, X)
                
                start_time = time.time()
                scores = cross_val_score(full_pipeline, X, y, cv=3, scoring='roc_auc', error_score='raise')
                duration = time.time() - start_time
                
                mean_score = np.mean(scores)
                
                print(f"  > {model_name:<20} | AUC: {mean_score:.4f} | {duration:.2f}s")
                
                results.append({
                    'Dataset': d_name,
                    'Difficulty': 'Hard' if d_id in [1485, 1479, 40994] else 'Easy/Std',
                    'Model': model_name,
                    'Mean_AUC': mean_score,
                    'Time_Sec': duration
                })
                
            except Exception as e:
                print(f"  ! Error with model {model_name}")
    if not results: 
        print("Brak wyników.")
        return

    df_res = pd.DataFrame(results)
    
    print("\n" + "="*80)
    print(f"{' SUMMARY ':^80}")
    print("="*80)
    
    pivot = df_res.pivot_table(index='Model', columns='Dataset', values='Mean_AUC')
    
    pivot['Global_Avg'] = pivot.mean(axis=1)
    pivot = pivot.sort_values('Global_Avg', ascending=False)
    
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    pd.set_option('display.precision', 4)
    print(pivot)

    filename = 'results.csv'
    pivot.to_csv(filename)
    print(f"\nSaved in: {filename}")

# %%
run('models_for_tests.json')
# Out:
# Loaded 47 models from file 'models_for_tests.json'
#
# --- RUNDA: WBC (Breast Cancer) ---
# Loaded dataset WBC (Breast Cancer) (ID: 1510) with 569 samples and 30 features.
#   > log_reg1             | AUC: 0.9960 | 0.25s
#   > log_reg2             | AUC: 0.9959 | 6.81s
#   > log_reg3             | AUC: 0.9949 | 0.58s
#   > log_reg4             | AUC: 0.9938 | 0.17s
#   > log_reg5             | AUC: 0.9925 | 0.13s
#   > lda1                 | AUC: 0.9925 | 0.14s
#   > lda2                 | AUC: 0.9900 | 0.14s
#   > ridge_clf            | AUC: 0.9915 | 0.13s
#   > decision_tree1       | AUC: 0.9104 | 0.14s
#   > decision_tree2       | AUC: 0.8677 | 0.13s
#   > decision_tree3       | AUC: 0.9510 | 0.14s
#   > decision_tree4       | AUC: 0.9301 | 0.15s
#   > decision_tree5       | AUC: 0.9180 | 0.22s
#   > random_forest1       | AUC: 0.9903 | 0.52s
#   > random_forest2       | AUC: 0.9906 | 1.23s
#   > random_forest3       | AUC: 0.9876 | 1.82s
#   > random_forest4       | AUC: 0.9915 | 0.87s
#   > extra_trees1         | AUC: 0.9931 | 0.60s
#   > extra_trees2         | AUC: 0.9921 | 0.92s
#   > xgboost1             | AUC: 0.9930 | 0.44s
#   > xgboost2             | AUC: 0.9937 | 0.99s
#   > xgboost3             | AUC: 0.9926 | 0.52s
#   > xgboost4             | AUC: 0.9939 | 2.90s
#   > xgboost5             | AUC: 0.9906 | 0.50s
#   > xgboost6             | AUC: 0.9929 | 0.96s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.9908 | 0.20s
#   > knn2                 | AUC: 0.9888 | 0.14s
#   > knn3                 | AUC: 0.9925 | 0.15s
#   > knn4                 | AUC: 0.9894 | 0.15s
#   > svm1                 | AUC: 0.9964 | 0.16s
#   > svm2                 | AUC: 0.9951 | 0.14s
#   > svm3                 | AUC: 0.9949 | 0.16s
#   > svm4                 | AUC: 0.9939 | 0.17s
#   > gaussian_nb          | AUC: 0.9865 | 0.13s
#   > bernoulli_nb1        | AUC: 0.9746 | 0.14s
#   > bernoulli_nb2        | AUC: 0.9745 | 0.20s
#   > ada_boost1           | AUC: 0.9932 | 0.78s
#   > ada_boost2           | AUC: 0.9904 | 1.38s
#   > gradient_boosting    | AUC: 0.9883 | 0.77s
#   > hist_gradient_boosting | AUC: 0.9926 | 1.73s
#
# --- RUNDA: Banknote Auth ---
# Loaded dataset Banknote Auth (ID: 1462) with 1372 samples and 4 features.
#   > log_reg1             | AUC: 1.0000 | 0.09s
#   > log_reg2             | AUC: 1.0000 | 2.12s
#   > log_reg3             | AUC: 1.0000 | 0.08s
#   > log_reg4             | AUC: 1.0000 | 0.09s
#   > log_reg5             | AUC: 0.9951 | 0.04s
#   > lda1                 | AUC: 1.0000 | 0.05s
#   > lda2                 | AUC: 1.0000 | 0.04s
#   > ridge_clf            | AUC: 1.0000 | 0.04s
#   > decision_tree1       | AUC: 0.9870 | 0.05s
#   > decision_tree2       | AUC: 0.8547 | 0.05s
#   > decision_tree3       | AUC: 0.9918 | 0.06s
#   > decision_tree4       | AUC: 0.9860 | 0.05s
#   > decision_tree5       | AUC: 0.9789 | 0.05s
#   > random_forest1       | AUC: 0.9999 | 0.45s
#   > random_forest2       | AUC: 0.9998 | 1.24s
#   > random_forest3       | AUC: 0.9997 | 2.01s
#   > random_forest4       | AUC: 0.9999 | 0.89s
#   > extra_trees1         | AUC: 1.0000 | 0.56s
#   > extra_trees2         | AUC: 1.0000 | 0.94s
#   > xgboost1             | AUC: 0.9999 | 0.31s
#   > xgboost2             | AUC: 1.0000 | 1.11s
#   > xgboost3             | AUC: 0.9999 | 0.47s
#   > xgboost4             | AUC: 0.9999 | 3.84s
#   > xgboost5             | AUC: 0.9999 | 0.54s
#   > xgboost6             | AUC: 0.9998 | 0.90s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 1.0000 | 0.08s
#   > knn2                 | AUC: 1.0000 | 0.08s
#   > knn3                 | AUC: 0.9993 | 0.08s
#   > knn4                 | AUC: 1.0000 | 0.08s
#   > svm1                 | AUC: 1.0000 | 0.09s
#   > svm2                 | AUC: 1.0000 | 0.09s
#   > svm3                 | AUC: 0.9992 | 0.12s
#   > svm4                 | AUC: 1.0000 | 0.08s
#   > gaussian_nb          | AUC: 0.9593 | 0.04s
#   > bernoulli_nb1        | AUC: 0.9071 | 0.04s
#   > bernoulli_nb2        | AUC: 0.9071 | 0.04s
#   > ada_boost1           | AUC: 0.9998 | 0.43s
#   > ada_boost2           | AUC: 0.9936 | 0.81s
#   > gradient_boosting    | AUC: 0.9999 | 0.93s
#   > hist_gradient_boosting | AUC: 0.9996 | 1.83s
#
# --- RUNDA: Diabetes (Pima) ---
# Loaded dataset Diabetes (Pima) (ID: 37) with 768 samples and 8 features.
#   > log_reg1             | AUC: 0.8351 | 0.10s
#   > log_reg2             | AUC: 0.8354 | 2.14s
#   > log_reg3             | AUC: 0.8354 | 0.09s
#   > log_reg4             | AUC: 0.8344 | 0.10s
#   > log_reg5             | AUC: 0.8316 | 0.06s
#   > lda1                 | AUC: 0.8358 | 0.05s
#   > lda2                 | AUC: 0.8358 | 0.05s
#   > ridge_clf            | AUC: 0.8359 | 0.05s
#   > decision_tree1       | AUC: 0.7041 | 0.06s
#   > decision_tree2       | AUC: 0.6653 | 0.05s
#   > decision_tree3       | AUC: 0.7496 | 0.06s
#   > decision_tree4       | AUC: 0.6959 | 0.06s
#   > decision_tree5       | AUC: 0.6561 | 0.06s
#   > random_forest1       | AUC: 0.8254 | 0.38s
#   > random_forest2       | AUC: 0.8311 | 1.03s
#   > random_forest3       | AUC: 0.8355 | 1.59s
#   > random_forest4       | AUC: 0.8303 | 0.83s
#   > extra_trees1         | AUC: 0.8375 | 0.56s
#   > extra_trees2         | AUC: 0.8239 | 1.10s
#   > xgboost1             | AUC: 0.8169 | 0.34s
#   > xgboost2             | AUC: 0.8083 | 2.11s
#   > xgboost3             | AUC: 0.8080 | 0.66s
#   > xgboost4             | AUC: 0.8184 | 4.04s
#   > xgboost5             | AUC: 0.8154 | 0.90s
#   > xgboost6             | AUC: 0.8138 | 1.08s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.8065 | 0.10s
#   > knn2                 | AUC: 0.8115 | 0.09s
#   > knn3                 | AUC: 0.7694 | 0.09s
#   > knn4                 | AUC: 0.8278 | 0.10s
#   > svm1                 | AUC: 0.8247 | 0.14s
#   > svm2                 | AUC: 0.8366 | 0.11s
#   > svm3                 | AUC: 0.8096 | 0.13s
#   > svm4                 | AUC: 0.7895 | 0.17s
#   > gaussian_nb          | AUC: 0.8287 | 0.05s
#   > bernoulli_nb1        | AUC: 0.7823 | 0.05s
#   > bernoulli_nb2        | AUC: 0.7823 | 0.06s
#   > ada_boost1           | AUC: 0.8265 | 0.37s
#   > ada_boost2           | AUC: 0.8269 | 0.75s
#   > gradient_boosting    | AUC: 0.8202 | 0.18s
#   > hist_gradient_boosting | AUC: 0.7933 | 2.14s
#
# --- RUNDA: Bank Marketing ---
# Loaded dataset Bank Marketing (ID: 1461) with 5000 samples and 16 features.
#   > log_reg1             | AUC: 0.9037 | 1.29s
#   > log_reg2             | AUC: 0.9036 | 4.27s
#   > log_reg3             | AUC: 0.9042 | 1.01s
#   > log_reg4             | AUC: 0.9032 | 0.99s
#   > log_reg5             | AUC: 0.8954 | 0.15s
#   > lda1                 | AUC: 0.9008 | 0.15s
#   > lda2                 | AUC: 0.8992 | 0.16s
#   > ridge_clf            | AUC: 0.9035 | 0.14s
#   > decision_tree1       | AUC: 0.8230 | 0.18s
#   > decision_tree2       | AUC: 0.6763 | 0.15s
#   > decision_tree3       | AUC: 0.7747 | 0.19s
#   > decision_tree4       | AUC: 0.7136 | 0.20s
#   > decision_tree5       | AUC: 0.6999 | 0.24s
#   > random_forest1       | AUC: 0.9065 | 1.01s
#   > random_forest2       | AUC: 0.9150 | 3.18s
#   > random_forest3       | AUC: 0.9129 | 4.45s
#   > random_forest4       | AUC: 0.9181 | 2.25s
#   > extra_trees1         | AUC: 0.8775 | 1.36s
#   > extra_trees2         | AUC: 0.8772 | 4.24s
#   > xgboost1             | AUC: 0.9145 | 0.48s
#   > xgboost2             | AUC: 0.9110 | 2.38s
#   > xgboost3             | AUC: 0.9093 | 0.88s
#   > xgboost4             | AUC: 0.9186 | 5.33s
#   > xgboost5             | AUC: 0.9106 | 1.57s
#   > xgboost6             | AUC: 0.9140 | 1.53s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.8679 | 0.25s
#   > knn2                 | AUC: 0.8815 | 0.37s
#   > knn3                 | AUC: 0.7969 | 0.27s
#   > knn4                 | AUC: 0.8720 | 0.64s
#   > svm1                 | AUC: 0.9090 | 4.61s
#   > svm2                 | AUC: 0.9050 | 2.89s
#   > svm3                 | AUC: 0.8944 | 2.79s
#   > svm4                 | AUC: 0.8878 | 3.42s
#   > gaussian_nb          | AUC: 0.7646 | 0.17s
#   > bernoulli_nb1        | AUC: 0.7850 | 0.15s
#   > bernoulli_nb2        | AUC: 0.7849 | 0.14s
#   > ada_boost1           | AUC: 0.8899 | 1.14s
#   > ada_boost2           | AUC: 0.8793 | 2.14s
#   > gradient_boosting    | AUC: 0.9134 | 1.35s
#   > hist_gradient_boosting | AUC: 0.9077 | 4.60s
#
# --- RUNDA: PC4 (Software Defect) ---
# Loaded dataset PC4 (Software Defect) (ID: 1049) with 1458 samples and 37 features.
#   > log_reg1             | AUC: 0.9248 | 0.56s
#   > log_reg2             | AUC: 0.9230 | 2.14s
#   > log_reg3             | AUC: 0.9286 | 1.12s
#   > log_reg4             | AUC: 0.9170 | 0.32s
#   > log_reg5             | AUC: 0.9048 | 0.21s
#   > lda1                 | AUC: 0.9078 | 0.21s
#   > lda2                 | AUC: 0.9055 | 0.27s
#   > ridge_clf            | AUC: 0.9119 | 0.20s
#   > decision_tree1       | AUC: 0.8377 | 0.23s
#   > decision_tree2       | AUC: 0.8361 | 0.20s
#   > decision_tree3       | AUC: 0.8040 | 0.23s
#   > decision_tree4       | AUC: 0.7426 | 0.23s
#   > decision_tree5       | AUC: 0.7208 | 0.22s
#   > random_forest1       | AUC: 0.9222 | 0.73s
#   > random_forest2       | AUC: 0.9282 | 1.90s
#   > random_forest3       | AUC: 0.9265 | 2.89s
#   > random_forest4       | AUC: 0.9315 | 1.40s
#   > extra_trees1         | AUC: 0.9215 | 0.82s
#   > extra_trees2         | AUC: 0.9269 | 1.59s
#   > xgboost1             | AUC: 0.9390 | 0.55s
#   > xgboost2             | AUC: 0.9395 | 2.06s
#   > xgboost3             | AUC: 0.9378 | 0.84s
#   > xgboost4             | AUC: 0.9387 | 4.42s
#   > xgboost5             | AUC: 0.9387 | 1.06s
#   > xgboost6             | AUC: 0.9392 | 1.42s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.8923 | 0.21s
#   > knn2                 | AUC: 0.8980 | 0.21s
#   > knn3                 | AUC: 0.8511 | 0.20s
#   > knn4                 | AUC: 0.8831 | 0.23s
#   > svm1                 | AUC: 0.9192 | 0.53s
#   > svm2                 | AUC: 0.9224 | 0.38s
#   > svm3                 | AUC: 0.8900 | 0.47s
#   > svm4                 | AUC: 0.9172 | 0.44s
#   > gaussian_nb          | AUC: 0.8459 | 0.20s
#   > bernoulli_nb1        | AUC: 0.8314 | 0.20s
#   > bernoulli_nb2        | AUC: 0.8301 | 0.20s
#   > ada_boost1           | AUC: 0.9323 | 0.99s
#   > ada_boost2           | AUC: 0.9172 | 1.69s
#   > gradient_boosting    | AUC: 0.9310 | 0.68s
#   > hist_gradient_boosting | AUC: 0.9359 | 2.71s
#
# --- RUNDA: Blood Transfusion ---
# Loaded dataset Blood Transfusion (ID: 1464) with 748 samples and 4 features.
#   > log_reg1             | AUC: 0.8302 | 0.08s
#   > log_reg2             | AUC: 0.8293 | 0.09s
#   > log_reg3             | AUC: 0.8293 | 0.12s
#   > log_reg4             | AUC: 0.8262 | 0.08s
#   > log_reg5             | AUC: 0.8123 | 0.04s
#   > lda1                 | AUC: 0.8217 | 0.04s
#   > lda2                 | AUC: 0.8232 | 0.04s
#   > ridge_clf            | AUC: 0.8256 | 0.04s
#   > decision_tree1       | AUC: 0.6788 | 0.04s
#   > decision_tree2       | AUC: 0.6824 | 0.03s
#   > decision_tree3       | AUC: 0.6400 | 0.04s
#   > decision_tree4       | AUC: 0.5909 | 0.04s
#   > decision_tree5       | AUC: 0.6000 | 0.03s
#   > random_forest1       | AUC: 0.6448 | 0.31s
#   > random_forest2       | AUC: 0.6737 | 0.85s
#   > random_forest3       | AUC: 0.7157 | 1.34s
#   > random_forest4       | AUC: 0.6585 | 0.61s
#   > extra_trees1         | AUC: 0.7021 | 0.51s
#   > extra_trees2         | AUC: 0.6212 | 0.93s
#   > xgboost1             | AUC: 0.6780 | 0.31s
#   > xgboost2             | AUC: 0.6270 | 1.73s
#   > xgboost3             | AUC: 0.6477 | 0.58s
#   > xgboost4             | AUC: 0.6632 | 3.72s
#   > xgboost5             | AUC: 0.7390 | 0.45s
#   > xgboost6             | AUC: 0.6668 | 0.96s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.6517 | 0.08s
#   > knn2                 | AUC: 0.6769 | 0.07s
#   > knn3                 | AUC: 0.6212 | 0.07s
#   > knn4                 | AUC: 0.6954 | 0.07s
#   > svm1                 | AUC: 0.7309 | 0.12s
#   > svm2                 | AUC: 0.8186 | 0.09s
#   > svm3                 | AUC: 0.7495 | 0.12s
#   > svm4                 | AUC: 0.6726 | 0.14s
#   > gaussian_nb          | AUC: 0.7721 | 0.03s
#   > bernoulli_nb1        | AUC: 0.6945 | 0.03s
#   > bernoulli_nb2        | AUC: 0.6945 | 0.03s
#   > ada_boost1           | AUC: 0.7897 | 0.28s
#   > ada_boost2           | AUC: 0.8146 | 0.53s
#   > gradient_boosting    | AUC: 0.7163 | 0.11s
#   > hist_gradient_boosting | AUC: 0.6595 | 1.89s
#
# --- RUNDA: Madelon ---
# Loaded dataset Madelon (ID: 1485) with 2600 samples and 500 features.
#   > log_reg1             | AUC: 0.5696 | 11.55s
#   > log_reg2             | AUC: 0.5696 | 6.68s
#   > log_reg3             | AUC: 0.5758 | 18.78s
#   > log_reg4             | AUC: 0.5842 | 9.45s
#   > log_reg5             | AUC: 0.5851 | 3.52s
#   > lda1                 | AUC: 0.6208 | 3.42s
#   > lda2                 | AUC: 0.5725 | 3.57s
#   > ridge_clf            | AUC: 0.5721 | 3.28s
#   > decision_tree1       | AUC: 0.7430 | 4.61s
#   > decision_tree2       | AUC: 0.6169 | 3.44s
#   > decision_tree3       | AUC: 0.7597 | 4.57s
#   > decision_tree4       | AUC: 0.7403 | 4.94s
#   > decision_tree5       | AUC: 0.7231 | 4.96s
#   > random_forest1       | AUC: 0.7592 | 8.12s
#   > random_forest2       | AUC: 0.7833 | 21.50s
#   > random_forest3       | AUC: 0.7791 | 28.99s
#   > random_forest4       | AUC: 0.7888 | 16.94s
#   > extra_trees1         | AUC: 0.6978 | 5.20s
#   > extra_trees2         | AUC: 0.7658 | 11.74s
#   > xgboost1             | AUC: 0.8360 | 4.92s
#   > xgboost2             | AUC: 0.8948 | 17.99s
#   > xgboost3             | AUC: 0.8800 | 9.17s
#   > xgboost4             | AUC: 0.8834 | 40.44s
#   > xgboost5             | AUC: 0.8742 | 11.60s
#   > xgboost6             | AUC: 0.8782 | 13.35s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.6067 | 3.27s
#   > knn2                 | AUC: 0.6257 | 3.30s
#   > knn3                 | AUC: 0.5593 | 3.25s
#   > knn4                 | AUC: 0.6904 | 3.82s
#   > svm1                 | AUC: 0.6263 | 13.20s
#   > svm2                 | AUC: 0.5720 | 25.72s
#   > svm3                 | AUC: 0.6337 | 11.49s
#   > svm4                 | AUC: 0.6150 | 13.41s
#   > gaussian_nb          | AUC: 0.6439 | 3.21s
#   > bernoulli_nb1        | AUC: 0.6313 | 3.25s
#   > bernoulli_nb2        | AUC: 0.6313 | 3.24s
#   > ada_boost1           | AUC: 0.6611 | 18.12s
#   > ada_boost2           | AUC: 0.6750 | 34.23s
#   > gradient_boosting    | AUC: 0.7898 | 27.02s
#   > hist_gradient_boosting | AUC: 0.8782 | 32.50s
#
# --- RUNDA: Hill-Valley ---
# Loaded dataset Hill-Valley (ID: 1479) with 1212 samples and 100 features.
#   > log_reg1             | AUC: 0.9328 | 1.48s
#   > log_reg2             | AUC: 0.9335 | 5.11s
#   > log_reg3             | AUC: 0.7169 | 5.98s
#   > log_reg4             | AUC: 0.5358 | 0.89s
#   > log_reg5             | AUC: 0.5562 | 0.43s
#   > lda1                 | AUC: 0.9642 | 0.45s
#   > lda2                 | AUC: 0.9908 | 0.45s
#   > ridge_clf            | AUC: 0.9727 | 0.44s
#   > decision_tree1       | AUC: 0.5091 | 0.65s
#   > decision_tree2       | AUC: 0.5124 | 0.44s
#   > decision_tree3       | AUC: 0.5466 | 0.63s
#   > decision_tree4       | AUC: 0.5588 | 0.76s
#   > decision_tree5       | AUC: 0.5586 | 0.83s
#   > random_forest1       | AUC: 0.5641 | 1.90s
#   > random_forest2       | AUC: 0.5668 | 6.90s
#   > random_forest3       | AUC: 0.5582 | 8.90s
#   > random_forest4       | AUC: 0.5778 | 7.04s
#   > extra_trees1         | AUC: 0.5605 | 1.29s
#   > extra_trees2         | AUC: 0.5976 | 3.23s
#   > xgboost1             | AUC: 0.5695 | 0.98s
#   > xgboost2             | AUC: 0.5732 | 3.74s
#   > xgboost3             | AUC: 0.5655 | 1.62s
#   > xgboost4             | AUC: 0.5681 | 7.41s
#   > xgboost5             | AUC: 0.5652 | 2.63s
#   > xgboost6             | AUC: 0.5533 | 2.64s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.5346 | 0.44s
#   > knn2                 | AUC: 0.5296 | 0.48s
#   > knn3                 | AUC: 0.5147 | 0.67s
#   > knn4                 | AUC: 0.5295 | 0.73s
#   > svm1                 | AUC: 0.5898 | 1.24s
#   > svm2                 | AUC: 0.6126 | 0.91s
#   > svm3                 | AUC: 0.5591 | 0.92s
#   > svm4                 | AUC: 0.6479 | 1.13s
#   > gaussian_nb          | AUC: 0.5354 | 0.42s
#   > bernoulli_nb1        | AUC: 0.5430 | 0.42s
#   > bernoulli_nb2        | AUC: 0.5430 | 0.42s
#   > ada_boost1           | AUC: 0.5170 | 3.27s
#   > ada_boost2           | AUC: 0.5268 | 6.13s
#   > gradient_boosting    | AUC: 0.5313 | 1.14s
#   > hist_gradient_boosting | AUC: 0.5751 | 3.55s
#
# --- RUNDA: Climate Crashes ---
# Loaded dataset Climate Crashes (ID: 40994) with 540 samples and 18 features.
#   > log_reg1             | AUC: 0.9158 | 0.50s
#   > log_reg2             | AUC: 0.9522 | 3.51s
#   > log_reg3             | AUC: 0.9201 | 0.71s
#   > log_reg4             | AUC: 0.9490 | 0.12s
#   > log_reg5             | AUC: 0.9454 | 0.08s
#   > lda1                 | AUC: 0.9455 | 0.09s
#   > lda2                 | AUC: 0.9459 | 0.08s
#   > ridge_clf            | AUC: 0.9442 | 0.09s
#   > decision_tree1       | AUC: 0.7338 | 0.09s
#   > decision_tree2       | AUC: 0.6852 | 0.08s
#   > decision_tree3       | AUC: 0.7854 | 0.09s
#   > decision_tree4       | AUC: 0.6676 | 0.09s
#   > decision_tree5       | AUC: 0.6823 | 0.09s
#   > random_forest1       | AUC: 0.9237 | 0.40s
#   > random_forest2       | AUC: 0.9158 | 1.09s
#   > random_forest3       | AUC: 0.9398 | 1.60s
#   > random_forest4       | AUC: 0.9292 | 0.75s
#   > extra_trees1         | AUC: 0.9536 | 0.55s
#   > extra_trees2         | AUC: 0.9495 | 0.87s
#   > xgboost1             | AUC: 0.9392 | 0.35s
#   > xgboost2             | AUC: 0.9386 | 1.03s
#   > xgboost3             | AUC: 0.9392 | 0.48s
#   > xgboost4             | AUC: 0.9455 | 2.77s
#   > xgboost5             | AUC: 0.9309 | 0.43s
#   > xgboost6             | AUC: 0.9361 | 0.90s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.9113 | 0.09s
#   > knn2                 | AUC: 0.9279 | 0.11s
#   > knn3                 | AUC: 0.8380 | 0.14s
#   > knn4                 | AUC: 0.9215 | 0.15s
#   > svm1                 | AUC: 0.9361 | 0.19s
#   > svm2                 | AUC: 0.9414 | 0.14s
#   > svm3                 | AUC: 0.9004 | 0.14s
#   > svm4                 | AUC: 0.9385 | 0.12s
#   > gaussian_nb          | AUC: 0.9491 | 0.09s
#   > bernoulli_nb1        | AUC: 0.9313 | 0.09s
#   > bernoulli_nb2        | AUC: 0.9306 | 0.09s
#   > ada_boost1           | AUC: 0.9231 | 0.56s
#   > ada_boost2           | AUC: 0.9248 | 1.05s
#   > gradient_boosting    | AUC: 0.8870 | 0.38s
#   > hist_gradient_boosting | AUC: 0.9395 | 1.01s
#
# --- RUNDA: German Credit ---
# Loaded dataset German Credit (ID: 31) with 1000 samples and 20 features.
#   > log_reg1             | AUC: 0.7873 | 0.36s
#   > log_reg2             | AUC: 0.7876 | 3.41s
#   > log_reg3             | AUC: 0.7886 | 0.16s
#   > log_reg4             | AUC: 0.7835 | 0.17s
#   > log_reg5             | AUC: 0.7790 | 0.08s
#   > lda1                 | AUC: 0.7885 | 0.08s
#   > lda2                 | AUC: 0.7836 | 0.08s
#   > ridge_clf            | AUC: 0.7885 | 0.07s
#   > decision_tree1       | AUC: 0.7074 | 0.08s
#   > decision_tree2       | AUC: 0.6719 | 0.07s
#   > decision_tree3       | AUC: 0.6721 | 0.08s
#   > decision_tree4       | AUC: 0.6461 | 0.08s
#   > decision_tree5       | AUC: 0.6083 | 0.08s
#   > random_forest1       | AUC: 0.7974 | 0.41s
#   > random_forest2       | AUC: 0.7963 | 1.09s
#   > random_forest3       | AUC: 0.7986 | 1.59s
#   > random_forest4       | AUC: 0.7975 | 0.80s
#   > extra_trees1         | AUC: 0.7877 | 0.68s
#   > extra_trees2         | AUC: 0.7781 | 1.52s
#   > xgboost1             | AUC: 0.7903 | 0.35s
#   > xgboost2             | AUC: 0.7824 | 1.83s
#   > xgboost3             | AUC: 0.7745 | 0.65s
#   > xgboost4             | AUC: 0.7905 | 3.88s
#   > xgboost5             | AUC: 0.7783 | 1.05s
#   > xgboost6             | AUC: 0.7748 | 1.04s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.7446 | 0.08s
#   > knn2                 | AUC: 0.7611 | 0.08s
#   > knn3                 | AUC: 0.7233 | 0.08s
#   > knn4                 | AUC: 0.7771 | 0.10s
#   > svm1                 | AUC: 0.7890 | 0.41s
#   > svm2                 | AUC: 0.7841 | 0.25s
#   > svm3                 | AUC: 0.7758 | 0.28s
#   > svm4                 | AUC: 0.7560 | 0.48s
#   > gaussian_nb          | AUC: 0.7330 | 0.07s
#   > bernoulli_nb1        | AUC: 0.7804 | 0.07s
#   > bernoulli_nb2        | AUC: 0.7800 | 0.07s
#   > ada_boost1           | AUC: 0.7815 | 0.44s
#   > ada_boost2           | AUC: 0.7645 | 0.81s
#   > gradient_boosting    | AUC: 0.7748 | 0.34s
#   > hist_gradient_boosting | AUC: 0.7647 | 2.05s
#
# --- RUNDA: Spambase ---
# Loaded dataset Spambase (ID: 44) with 4601 samples and 57 features.
#   > log_reg1             | AUC: 0.9735 | 1.00s
#   > log_reg2             | AUC: 0.9733 | 4.60s
#   > log_reg3             | AUC: 0.9742 | 1.19s
#   > log_reg4             | AUC: 0.9746 | 0.84s
#   > log_reg5             | AUC: 0.9730 | 0.48s
#   > lda1                 | AUC: 0.9722 | 0.47s
#   > lda2                 | AUC: 0.9720 | 0.48s
#   > ridge_clf            | AUC: 0.9722 | 0.46s
#   > decision_tree1       | AUC: 0.9253 | 0.54s
#   > decision_tree2       | AUC: 0.7503 | 0.46s
#   > decision_tree3       | AUC: 0.9142 | 0.56s
#   > decision_tree4       | AUC: 0.8944 | 0.61s
#   > decision_tree5       | AUC: 0.8713 | 0.63s
#   > random_forest1       | AUC: 0.9714 | 1.60s
#   > random_forest2       | AUC: 0.9713 | 4.36s
#   > random_forest3       | AUC: 0.9708 | 6.30s
#   > random_forest4       | AUC: 0.9742 | 3.14s
#   > extra_trees1         | AUC: 0.9732 | 1.59s
#   > extra_trees2         | AUC: 0.9758 | 3.86s
#   > xgboost1             | AUC: 0.9757 | 0.85s
#   > xgboost2             | AUC: 0.9776 | 2.78s
#   > xgboost3             | AUC: 0.9772 | 1.30s
#   > xgboost4             | AUC: 0.9775 | 5.51s
#   > xgboost5             | AUC: 0.9754 | 1.93s
#   > xgboost6             | AUC: 0.9775 | 1.78s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.9635 | 0.49s
#   > knn2                 | AUC: 0.9644 | 0.50s
#   > knn3                 | AUC: 0.9513 | 0.62s
#   > knn4                 | AUC: 0.9656 | 0.94s
#   > svm1                 | AUC: 0.9731 | 2.89s
#   > svm2                 | AUC: 0.9735 | 1.51s
#   > svm3                 | AUC: 0.9730 | 2.66s
#   > svm4                 | AUC: 0.9715 | 2.70s
#   > gaussian_nb          | AUC: 0.9485 | 0.46s
#   > bernoulli_nb1        | AUC: 0.9563 | 0.51s
#   > bernoulli_nb2        | AUC: 0.9560 | 0.46s
#   > ada_boost1           | AUC: 0.9715 | 2.00s
#   > ada_boost2           | AUC: 0.9682 | 3.55s
#   > gradient_boosting    | AUC: 0.9740 | 5.06s
#   > hist_gradient_boosting | AUC: 0.9769 | 6.91s
#
# --- RUNDA: QSAR Biodeg ---
# Loaded dataset QSAR Biodeg (ID: 1494) with 1055 samples and 41 features.
#   > log_reg1             | AUC: 0.9002 | 0.56s
#   > log_reg2             | AUC: 0.9022 | 0.24s
#   > log_reg3             | AUC: 0.9015 | 0.62s
#   > log_reg4             | AUC: 0.8998 | 0.36s
#   > log_reg5             | AUC: 0.8960 | 0.19s
#   > lda1                 | AUC: 0.8966 | 0.19s
#   > lda2                 | AUC: 0.8922 | 0.19s
#   > ridge_clf            | AUC: 0.8939 | 0.19s
#   > decision_tree1       | AUC: 0.8033 | 0.22s
#   > decision_tree2       | AUC: 0.6955 | 0.19s
#   > decision_tree3       | AUC: 0.8424 | 0.21s
#   > decision_tree4       | AUC: 0.8251 | 0.22s
#   > decision_tree5       | AUC: 0.7914 | 0.21s
#   > random_forest1       | AUC: 0.9170 | 0.66s
#   > random_forest2       | AUC: 0.9152 | 1.58s
#   > random_forest3       | AUC: 0.9146 | 2.36s
#   > random_forest4       | AUC: 0.9180 | 1.21s
#   > extra_trees1         | AUC: 0.9189 | 0.78s
#   > extra_trees2         | AUC: 0.9128 | 1.46s
#   > xgboost1             | AUC: 0.9213 | 0.50s
#   > xgboost2             | AUC: 0.9189 | 1.99s
#   > xgboost3             | AUC: 0.9160 | 0.84s
#   > xgboost4             | AUC: 0.9209 | 4.35s
#   > xgboost5             | AUC: 0.9159 | 1.07s
#   > xgboost6             | AUC: 0.9140 | 1.30s
#   ! Error with model catboost1
#   ! Error with model catboost2
#   ! Error with model catboost3
#   ! Error with model catboost4
#   ! Error with model catboost5
#   ! Error with model catboost6
#   ! Error with model catboost7
#   > knn1                 | AUC: 0.8933 | 0.21s
#   > knn2                 | AUC: 0.8943 | 0.30s
#   > knn3                 | AUC: 0.8827 | 0.32s
#   > knn4                 | AUC: 0.8993 | 0.34s
#   > svm1                 | AUC: 0.9061 | 0.50s
#   > svm2                 | AUC: 0.8999 | 0.30s
#   > svm3                 | AUC: 0.8771 | 0.33s
#   > svm4                 | AUC: 0.9086 | 0.38s
#   > gaussian_nb          | AUC: 0.8698 | 0.19s
#   > bernoulli_nb1        | AUC: 0.8673 | 0.19s
#   > bernoulli_nb2        | AUC: 0.8665 | 0.19s
#   > ada_boost1           | AUC: 0.9016 | 0.81s
#   > ada_boost2           | AUC: 0.8760 | 1.43s
#   > gradient_boosting    | AUC: 0.9131 | 1.03s
#   > hist_gradient_boosting | AUC: 0.9132 | 2.14s
#
# ================================================================================
#                                     SUMMARY
# ================================================================================
# Dataset                 Bank Marketing  Banknote Auth  Blood Transfusion  Climate Crashes  Diabetes (Pima)  German Credit  Hill-Valley  Madelon  PC4 (Software Defect)  QSAR Biodeg  Spambase  WBC (Breast Cancer)  Global_Avg
# Model
# lda1                            0.9008         1.0000             0.8217           0.9455           0.8358         0.7885       0.9642   0.6208                 0.9078       0.8966    0.9722               0.9925      0.8872
# ridge_clf                       0.9035         1.0000             0.8256           0.9442           0.8359         0.7885       0.9727   0.5721                 0.9119       0.8939    0.9722               0.9915      0.8843
# lda2                            0.8992         1.0000             0.8232           0.9459           0.8358         0.7836       0.9908   0.5725                 0.9055       0.8922    0.9720               0.9900      0.8842
# log_reg2                        0.9036         1.0000             0.8293           0.9522           0.8354         0.7876       0.9335   0.5696                 0.9230       0.9022    0.9733               0.9959      0.8838
# log_reg1                        0.9037         1.0000             0.8302           0.9158           0.8351         0.7873       0.9328   0.5696                 0.9248       0.9002    0.9735               0.9960      0.8808
# xgboost5                        0.9106         0.9999             0.7390           0.9309           0.8154         0.7783       0.5652   0.8742                 0.9387       0.9159    0.9754               0.9906      0.8695
# xgboost4                        0.9186         0.9999             0.6632           0.9455           0.8184         0.7905       0.5681   0.8834                 0.9387       0.9209    0.9775               0.9939      0.8682
# xgboost1                        0.9145         0.9999             0.6780           0.9392           0.8169         0.7903       0.5695   0.8360                 0.9390       0.9213    0.9757               0.9930      0.8644
# log_reg3                        0.9042         1.0000             0.8293           0.9201           0.8354         0.7886       0.7169   0.5758                 0.9286       0.9015    0.9742               0.9949      0.8641
# xgboost2                        0.9110         1.0000             0.6270           0.9386           0.8083         0.7824       0.5732   0.8948                 0.9395       0.9189    0.9776               0.9937      0.8637
# xgboost6                        0.9140         0.9998             0.6668           0.9361           0.8138         0.7748       0.5533   0.8782                 0.9392       0.9140    0.9775               0.9929      0.8634
# xgboost3                        0.9093         0.9999             0.6477           0.9392           0.8080         0.7745       0.5655   0.8800                 0.9378       0.9160    0.9772               0.9926      0.8623
# random_forest3                  0.9129         0.9997             0.7157           0.9398           0.8355         0.7986       0.5582   0.7791                 0.9265       0.9146    0.9708               0.9876      0.8616
# hist_gradient_boosting          0.9077         0.9996             0.6595           0.9395           0.7933         0.7647       0.5751   0.8782                 0.9359       0.9132    0.9769               0.9926      0.8614
# random_forest4                  0.9181         0.9999             0.6585           0.9292           0.8303         0.7975       0.5778   0.7888                 0.9315       0.9180    0.9742               0.9915      0.8596
# random_forest2                  0.9150         0.9998             0.6737           0.9158           0.8311         0.7963       0.5668   0.7833                 0.9282       0.9152    0.9713               0.9906      0.8573
# svm2                            0.9050         1.0000             0.8186           0.9414           0.8366         0.7841       0.6126   0.5720                 0.9224       0.8999    0.9735               0.9951      0.8551
# gradient_boosting               0.9134         0.9999             0.7163           0.8870           0.8202         0.7748       0.5313   0.7898                 0.9310       0.9131    0.9740               0.9883      0.8533
# extra_trees1                    0.8775         1.0000             0.7021           0.9536           0.8375         0.7877       0.5605   0.6978                 0.9215       0.9189    0.9732               0.9931      0.8520
# random_forest1                  0.9065         0.9999             0.6448           0.9237           0.8254         0.7974       0.5641   0.7592                 0.9222       0.9170    0.9714               0.9903      0.8518
# extra_trees2                    0.8772         1.0000             0.6212           0.9495           0.8239         0.7781       0.5976   0.7658                 0.9269       0.9128    0.9758               0.9921      0.8517
# log_reg4                        0.9032         1.0000             0.8262           0.9490           0.8344         0.7835       0.5358   0.5842                 0.9170       0.8998    0.9746               0.9938      0.8501
# svm1                            0.9090         1.0000             0.7309           0.9361           0.8247         0.7890       0.5898   0.6263                 0.9192       0.9061    0.9731               0.9964      0.8500
# ada_boost1                      0.8899         0.9998             0.7897           0.9231           0.8265         0.7815       0.5170   0.6611                 0.9323       0.9016    0.9715               0.9932      0.8489
# log_reg5                        0.8954         0.9951             0.8123           0.9454           0.8316         0.7790       0.5562   0.5851                 0.9048       0.8960    0.9730               0.9925      0.8472
# ada_boost2                      0.8793         0.9936             0.8146           0.9248           0.8269         0.7645       0.5268   0.6750                 0.9172       0.8760    0.9682               0.9904      0.8464
# svm4                            0.8878         1.0000             0.6726           0.9385           0.7895         0.7560       0.6479   0.6150                 0.9172       0.9086    0.9715               0.9939      0.8416
# svm3                            0.8944         0.9992             0.7495           0.9004           0.8096         0.7758       0.5591   0.6337                 0.8900       0.8771    0.9730               0.9949      0.8381
# knn4                            0.8720         1.0000             0.6954           0.9215           0.8278         0.7771       0.5295   0.6904                 0.8831       0.8993    0.9656               0.9894      0.8376
# knn2                            0.8815         1.0000             0.6769           0.9279           0.8115         0.7611       0.5296   0.6257                 0.8980       0.8943    0.9644               0.9888      0.8300
# knn1                            0.8679         1.0000             0.6517           0.9113           0.8065         0.7446       0.5346   0.6067                 0.8923       0.8933    0.9635               0.9908      0.8219
# gaussian_nb                     0.7646         0.9593             0.7721           0.9491           0.8287         0.7330       0.5354   0.6439                 0.8459       0.8698    0.9485               0.9865      0.8197
# bernoulli_nb1                   0.7850         0.9071             0.6945           0.9313           0.7823         0.7804       0.5430   0.6313                 0.8314       0.8673    0.9563               0.9746      0.8070
# bernoulli_nb2                   0.7849         0.9071             0.6945           0.9306           0.7823         0.7800       0.5430   0.6313                 0.8301       0.8665    0.9560               0.9745      0.8067
# knn3                            0.7969         0.9993             0.6212           0.8380           0.7694         0.7233       0.5147   0.5593                 0.8511       0.8827    0.9513               0.9925      0.7917
# decision_tree3                  0.7747         0.9918             0.6400           0.7854           0.7496         0.6721       0.5466   0.7597                 0.8040       0.8424    0.9142               0.9510      0.7860
# decision_tree1                  0.8230         0.9870             0.6788           0.7338           0.7041         0.7074       0.5091   0.7430                 0.8377       0.8033    0.9253               0.9104      0.7802
# decision_tree4                  0.7136         0.9860             0.5909           0.6676           0.6959         0.6461       0.5588   0.7403                 0.7426       0.8251    0.8944               0.9301      0.7493
# decision_tree5                  0.6999         0.9789             0.6000           0.6823           0.6561         0.6083       0.5586   0.7231                 0.7208       0.7914    0.8713               0.9180      0.7340
# decision_tree2                  0.6763         0.8547             0.6824           0.6852           0.6653         0.6719       0.5124   0.6169                 0.8361       0.6955    0.7503               0.8677      0.7095
#
# Saved in: results.csv

# %% [markdown]
# Zredukowałyśmy pulę z 50 do 30 modeli, aby odsiać konfiguracje nieefektywne, które mogłyby zaszumić wynik końcowego ensamblu, oraz aby zoptymalizować czas obliczeń, skupiając zasoby tylko na najbardziej obiecujących algorytmach.
# Strategia selekcji:
#  1. Scoring: Średnia AUC skorygowana o odchylenie standardowe (kara za niestabilność).
#     Formula: Score = Mean_AUC - (PENALTY_FACTOR * Volatility).
#  2. Etap 1 (Diversity): Wybór po jednym najlepszym reprezentancie z każdej rodziny
#     (Linear, Geometry/Bayes, RandomForest, Boosting).
#  3. Etap 2 (Performance): Dopełnienie listy do 30 modeli na podstawie najwyższego Score.
#
# Kolejność konfiguracji w pliku wyjściowym została zoptymalizowana pod kątem ograniczeń czasowych. Na szczycie listy priorytetów umieszczono liderów poszczególnych rodzin algorytmicznych. Taka strategia gwarantuje, że w przypadku konieczności przedwczesnego przerwania treningu, system będzie dysponował zróżnicowanym i stabilnym zestawem modeli bazowych, niezbędnym do skonstruowania skutecznego Ensemblu, unikając sytuacji, w której przetestowane zostałyby tylko modele jednego typu.

# %%
def detect_family(model_class):
    cls = model_class.lower()
    if 'linear' in cls or 'discriminant' in cls or 'ridge' in cls: 
        return 'Linear'
    if 'svm' in cls or 'neighbor' in cls or 'bayes' in cls: 
        return 'Geometry/Bayes'
    if 'randomforest' in cls or 'extratrees' in cls or 'decisiontree' in cls: 
        return 'RandomForest'
    if 'boost' in cls or 'lgbm' in cls: 
        return 'Boosting'
    return 'Other'

# %%
def run_optim(input_csv, input_models, output_json, penalty=0.15, size=30):
    if not os.path.exists(input_csv) or not os.path.exists(input_models):
        print(f" Missing {input_csv} or {input_models}")
        return
    df = pd.read_csv(input_csv)
    with open(input_models, 'r') as f:
        full_configs = json.load(f)
    
    config_map = {}
    for item in full_configs:
        if 'name' in item:
            item['family'] = detect_family(item.get('class', ''))
            config_map[item['name']] = item
    
    print(f"Len of scores{len(df)}, len of configs {len(config_map)}")

    cols = [c for c in df.columns if c not in ['Model', 'Global_Avg', 'Difficulty']]
    df['Real_Avg'] = df[cols].mean(axis=1)
    df['Volatility'] = df[cols].std(axis=1)
    df['Final_Score'] = df['Real_Avg'] - (penalty * df['Volatility'])
    df['Family'] = df['Model'].map(lambda x: config_map.get(x, {}).get('family', 'Unknown'))

    df = df.sort_values('Final_Score', ascending=False)
    final_models = []
    selected_names = set()

    families = ['Linear', 'Geometry/Bayes', 'RandomForest', 'Boosting']

    for fam in families:
        candidates = df[df['Family'] == fam]
        if not candidates.empty:
            winner = candidates.iloc[0]
            name = winner['Model']
            if name not in selected_names:
                final_models.append(name)
                selected_names.add(name)

    for _, row in df.iterrows():
        if len(final_models) >= size:
            break
        name = row['Model']
        if name not in selected_names:
            final_models.append(name)
            selected_names.add(name)
    output_list = []
    for name in final_models:
        if name in config_map:
            cfg = config_map[name].copy()
            if 'family' in cfg: del cfg['family']
            output_list.append(cfg)

    with open(output_json, 'w') as f:
        json.dump(output_list, f, indent=2)
    print(f"Saved {len(output_list)} selected models to {output_json}")

# %%
output_json = 'models.json'
input_json = 'models_for_tests.json'
input_csv = 'results.csv'

run_optim(input_csv, input_json, output_json, penalty=0.15, size=30)
# Out:
# Len of scores40, len of configs 47
# Saved 30 selected models to models.json

# %% [markdown]
# W ostatecznym systemie decydujemy się na wybór:
# * Preprocessing Danych:
#     - Dla zmiennych numerycznych stosujemy imputację medianą (SimpleImputer) oraz zaawansowaną transformację Yeo-Johnsona (PowerTransformer), która stabilizuje wariancję i normalizuje rozkłady cech.
#     - Dla zmiennych kategorycznych używamy imputacji stałą wartością ('missing') oraz kodowania One-Hot Encoding z obsługą nieznanych kategorii.
# * Strategia Selekcji:
#     - Wybór najlepszego algorytmu następuje na podstawie rankingu Balanced Accuracy, wyliczanego na wydzielonym zbiorze walidacyjnym (20% danych, podział stratyfikowany).
#     - Dla każdego modelu system automatycznie optymalizuje próg decyzyjny (threshold) w zakresie od 0.2 do 0.8, co jest kluczowe przy niezbalansowanych klasach.
#     - Proces selekcji jest ograniczony parametrami wydajnościowymi: maksymalnym czasem przeszukiwania (total_time_limit [default = 20 minut]) oraz limitem wierszy (max_rows_limit [default = 20000]) dla fazy turniejowej. total_time_limit nie jest w całości przeznaczony na fazę selekcji. Rezerwowane jest około 1/4 dostępnego czasu na trenowanie finalnego modelu na pełnym zbiorze danych
# * Ensembling:
#     - System buduje potencjalny model zespołowy VotingClassifier w trybie Soft Voting (uśrednianie prawdopodobieństw).
#     - Do głosowania wybierane jest TOP K (parametr top_k, domyślnie 5) najlepszych modeli z turnieju. Algorytm priorytetyzuje różnorodność, starając się w pierwszej kolejności dobrać liderów z różnych rodzin (np. Liniowe, Drzewa, Boosting), aby zredukować korelację błędów.
#     - Model zespołowy zostaje wybrany jako finalny tylko wtedy, gdy jego wynik walidacyjny przebija wynik najlepszego pojedynczego modelu (Single Model).
# * Finalny trening:
#     - Zwycięska konfiguracja jest trenowana ponownie na pełnym zbiorze danych (z zachowaniem parametru random_state dla powtarzalności).
#
# System MiniAutoML znajduje się w pliku automl.py.
#
# Konfiguracje przekazywane do init są w pliku models.json.
#
# Dodatkowo zdefiniowany został moduł run_function.py. Zawiera on funkcję sterującą, która przyjmuje ścieżkę do katalogu z danymi (X.csv, y.csv) i automatyzuje proces eksperymentalny.
# Przed uruchomieniem właściwego treningu, funkcja dokonuje podziału danych na zbiór treningowy (przekazywany do systemu AutoML) oraz zbiór testowy (ukryty przed systemem, służący do ostatecznej weryfikacji).
# Skrypt dostarcza również kluczowych statystyk, takich jak wymiary zbioru (liczba wierszy i cech) oraz balans klas. Po zakończeniu uczenia prezentuje wyniki wewnętrznego rankingu modeli (Leaderboard), a następnie ewaluuje zwycięski model na wydzielonym zbiorze testowym, raportując metryki skuteczności oraz automatycznie dobrany próg decyzyjny (threshold).
