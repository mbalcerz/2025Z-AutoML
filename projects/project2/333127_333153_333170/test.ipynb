# %%
from run_function import run_auto_ml

# %%
model1= run_auto_ml(data_dir="example_data", json_path="models.json")
# Out:
#                                   MINI AUTOML
# ...
# [DATA] Loading data from: 'example_data'
# [CONF] Configuration:     'models.json'
# [INFO] Dataset loaded:    3481 samples, 16 features
# [INFO] Class Balance:     Class False: 55.8% | Class True: 44.2%
# --------------------------------------------------------------------------------
# [TRAIN] Starting search (Time Budget: 5 min, Top-K: 5)...
# --- TIME BUDGET: 5 min (Search: 3.8 min) ---
# Preprocessing data...
# Starting model tournament...
# Model 1/30: lda1 -> BalAcc: 0.5573
# Model 2/30: svm2 -> BalAcc: 0.5586
# Model 3/30: random_forest3 -> BalAcc: 0.5499
# Model 4/30: xgboost5 -> BalAcc: 0.5615
# Model 5/30: ridge_clf -> BalAcc: 0.5526
# Model 6/30: lda2 -> BalAcc: 0.5553
# Model 7/30: log_reg2 -> BalAcc: 0.5553
# Model 8/30: log_reg1 -> BalAcc: 0.5526
# Model 9/30: xgboost4 -> BalAcc: 0.5543
# Model 10/30: log_reg3 -> BalAcc: 0.5567
# Model 11/30: xgboost1 -> BalAcc: 0.5536
# Model 12/30: xgboost2 -> BalAcc: 0.5692
# ...

# %%
# ID 37 openml
model2= run_auto_ml(data_dir="example_data_diabetes", json_path="models.json")
# Out:
#                                   MINI AUTOML
# ...
# [DATA] Loading data from: 'example_data_diabetes'
# [CONF] Configuration:     'models.json'
# [INFO] Dataset loaded:    768 samples, 8 features
# [INFO] Class Balance:     Class 0: 65.1% | Class 1: 34.9%
# --------------------------------------------------------------------------------
# [TRAIN] Starting search (Time Budget: 5 min, Top-K: 5)...
# --- TIME BUDGET: 5 min (Search: 3.8 min) ---
# Preprocessing data...
# Starting model tournament...
# Model 1/30: lda1 -> BalAcc: 0.7810
# Model 2/30: svm2 -> BalAcc: 0.7756
# Model 3/30: random_forest3 -> BalAcc: 0.7802
# Model 4/30: xgboost5 -> BalAcc: 0.7426
# Model 5/30: ridge_clf -> BalAcc: 0.7757
# Model 6/30: lda2 -> BalAcc: 0.7810
# Model 7/30: log_reg2 -> BalAcc: 0.7820
# Model 8/30: log_reg1 -> BalAcc: 0.7820
# Model 9/30: xgboost4 -> BalAcc: 0.7596
# Model 10/30: log_reg3 -> BalAcc: 0.7820
# Model 11/30: xgboost1 -> BalAcc: 0.7462
# Model 12/30: xgboost2 -> BalAcc: 0.7613
# ...

# %%
# id 1510 openml
model2= run_auto_ml(data_dir="example_data_breast_cancer", json_path="models.json")
# Out:
#                                   MINI AUTOML
# ...
# [DATA] Loading data from: 'example_data_breast_cancer'
# [CONF] Configuration:     'models.json'
# [INFO] Dataset loaded:    569 samples, 30 features
# [INFO] Class Balance:     Class 0: 62.7% | Class 1: 37.3%
# --------------------------------------------------------------------------------
# [TRAIN] Starting search (Time Budget: 5 min, Top-K: 5)...
# --- TIME BUDGET: 5 min (Search: 3.8 min) ---
# Preprocessing data...
# Starting model tournament...
# Model 1/30: lda1 -> BalAcc: 0.9706
# Model 2/30: svm2 -> BalAcc: 0.9706
# Model 3/30: random_forest3 -> BalAcc: 0.9618
# Model 4/30: catboost1 -> ERROR: No module named 'catboost'
# Model 5/30: ridge_clf -> BalAcc: 0.9443
# Model 6/30: lda2 -> BalAcc: 0.9706
# Model 7/30: log_reg2 -> BalAcc: 0.9706
# Model 8/30: log_reg1 -> BalAcc: 0.9706
# Model 9/30: xgboost5 -> ERROR: No module named 'xgboost'
# Model 10/30: catboost7 -> ERROR: No module named 'catboost'
# ...
